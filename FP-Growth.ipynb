# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Microsoft YaHei'  

from dask_jobqueue import SLURMCluster
from dask.distributed import Client
from glob import glob
import pandas as pd
import dask
import dask.dataframe as dd
from dask import delayed
import re
import pandas as pd
import jieba
from pyspark.sql import functions as F
from pyspark.sql import Window

import math
from pyspark.ml.fpm import FPGrowth
# Out:
# /home/yjia2/thesis/thesis/thesis/lib/python3.9/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
print(sc.uiWebUrl)
# Out:
# http://midway3-0141.rcc.local:4041

# %% [markdown]
# # Spark-based FP-growth preprocessing

# %% [markdown]
# ### Data and Computing Environment
#
# I used Spark on Midway3 to read a cleaned, segmented news corpus (People’s Daily) stored in Parquet. Parquet was chosen because its columnar storage and built-in statistics significantly reduce I/O overhead, facilitating large-scale distributed processing.
#
# - Field Selection and Type Standardization: Only select the "Year" and "Text Content_Cleansing" columns, and convert "Year" to int to unify the key type for subsequent grouping/slicing.
#
# - Tokenization into Item Arrays: Use `F.split(..., r"\s+")` to split the token column `items_raw` based on whitespace. The upstream cleansing process has already handled punctuation, special characters, and stop words
#
# - Document Deduplication: Use `F.array_distinct` to generate `items`, which converts "frequency representation" to "set representation."
#
# - Filtering Empty Transactions: Filter for `size(items) > 0` to avoid empty sets interfering with the model and statistics.
#
# - Sampling and Sorting Verification: Use `.show()` to verify the samples and sort by year, ensuring the data slicing logic is correct.
#
# - Set year = 1947, filter items for that year and use `.cache()`. Then use `.count()` to trigger a calculation to obtain the number of transactions for that year, which will serve as the training base and scale reference for subsequent FP-growth.

# %%
base = "cleaned_segmented_parquet"  
df = spark.read.parquet(base)

df = df.select(
    F.col("年份").cast("int").alias("year"),
    F.col("文本内容_清洗").alias("content_cleaned")
)

# %%
df_items = (df
    .withColumn("items_raw", F.split(F.col("content_cleaned"), r"\s+"))
    .withColumn("items", F.array_distinct(F.col("items_raw")))  
    .drop("items_raw")
    .filter(F.size("items") > 0))
df_items.select("year","items").show(5, truncate=False)
# Out:
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |year|items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |2010|[首届, 动漫, 版权保护, 贸易, 博览会, 本报, 广州, 月, 日电, 记者, 吴冰, 贺林平, 中国, 国际, 影视, 东莞, 这是, 全国, 第一个, 原创, 主题, 共有, 家, 企业, 参展, 国家广电总局, 广东省政府, 联合, 主办, 这一, 国, 字头, 展会, 旨在, 产业, 上, 下游, 衍生品, 生产, 整合, 打通, 助推, 转型, 升级, 据统计, 首日, 共, 达成, 版权, 交易, 成交, 意向, 项, 总金额, 高达, 亿元, 本次, 展览, 面积, 万多平方米, 设, 标准, 展位, 动漫展, 主线, 贯穿, 始终]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# |2010|[数字, 点击, 成就, 万吨, 截至, 年, 月, 日, 大庆油田, 生产, 原油, 天然气, 亿立方米, 稳产, 汪, 波, 宝, 峰, 亿元, 财政部, 会同, 民政部, 地方, 预拨, 城乡, 低保, 补助, 资金, 城市, 农村, 本报记者, 李丽辉, 万户, 甘肃, 地震, 灾区, 农村居民, 住房, 恢复, 重建, 全省, 万, 户, 维修, 已, 竣工, 林治波, 杨, 森, 公里, 上海, 轨道交通, 路网, 增至, 条, 线路, 运营, 总, 里程, 约, 投运, 车站, 座, 规模, 国内, 第一, 沈文敏]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# |2010|[福建, 铁路, 三线, 开通, 六线, 一站, 开工, 年, 月, 日, 福厦, 建设者, 欢呼雀跃, 当日, 温, 州, 福, 横, 峰福, 电气化, 改造, 峰, 南段, 正式, 合, 肥, 客运专线, 段, 赣, 龙, 岩, 扩能, 工程, 港尾, 三条, 疏港, 塘, 莆, 田, 三明, 北站, 动工, 海西, 铁路网, 建设, 大提速, 海峡西岸, 经济区, 长三角, 珠三角, 交流, 合作, 本报记者, 江宝章, 文, 蒋, 升阳, 摄]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |2010|[强化, 廉政, 意识, 弘扬, 新风, 正气, 深入开展, 反腐倡廉, 二, 九年, 宣传教育, 工作, 综述, 本报记者, 姜, 洁, 年, 纪检监察, 机关, 贯彻落实, 科学, 发展观, 党, 十七, 大, 十七届, 四中全会, 精神, 第十七届, 中央纪委, 第三, 第四次, 全会, 部署, 紧紧围绕, 党和国家, 中心, 锐意进取, 创新, 方式, 扎实, 各项, 党风廉政, 建设, 反腐败, 斗争, 营造, 社会舆论, 氛围, 先进事迹, 树立, 干部, 良好形象, 年初, 会同, 中央组织部, 中央宣传部, 中央, 学习, 实践, 活动, 领导小组, 联合, 宣传, 四川省, 南江县, 原, 县委, 常委, 纪委书记, 王瑛, 同志, 组织, 多家, 新闻媒体, 当年, 月, 当选, 位新, 中国, 成立, 感动, 人物, 战线, 上, 涌现出, 福建省, 福州市, 公安局, 党委, 副, 书记, 督察, 长, 盖起, 章, 广西壮族自治区, 贺州市, 钟山县, 优秀, 钟世才, 山东省, 济宁市, 泗水县, 国税局, 城区, 税务, 分局, 局长, 仲继刚, 湖南省, 长沙县, 金井, 镇, 综治办, 主任, 纪检, 专干, 汤, 杨, 先进人物, 恪尽职守, 淡泊名利, 政治, 品质, 求真务实, 真抓实干, 优良作风, 一身正气, 无私无畏, 精神境界, 广大干部, 群众, 热烈, 称赞, 教育, 筑牢, 党员干部, 思想道德, 防线, 建立健全, 制度, 监督, 并重, 惩治, 预防, 腐败体系, 实施, 纲要, 规划, 明确要求, 进一步, 加大, 示范, 警示, 岗位, 力度, 天津市, 评选, 名, 廉政勤政, 优秀党员, 辽宁, 全省, 百名, 勤廉, 兼优, 先进典型, 表彰大会, 教育室, 电教, 首都机场, 集团公司, 董事长, 李, 培英, 国家, 食品, 药品监督管理局, 郑筱萸, 郴州市, 系列, 腐败案, 典型, 腐败, 案件, 制作, 电教片, 充分利用, 黑龙江, 吉林, 浙江, 杭州, 试点工作, 教育引导, 公职人员, 岗位职责, 纪律, 规范, 履职, 河北, 重庆, 陕西, 新疆, 推进, 领导, 任前, 考试, 以考, 促学, 培育, 廉洁, 理念, 廉荣, 贪耻, 风尚, 部委, 制定, 廉政文化, 意见, 单位, 扬, 促, 和谐, 全国, 公益广告, 展播, 全, 社会, 强烈反响, 如火如荼, 重庆市, 举办, 故事, 大赛, 喜闻乐见, 讲故事, 形式, 讴歌, 新, 时代, 涌现, 原型, 拍摄, 影片, 北极雪, 多万名, 观看, 山东, 现代戏, 莱芜, 梆子, 儿行, 千里, 巡演, 场, 儒家, 思想, 论坛, 挖掘, 中华文化, 内涵, 河南, 创作, 豫剧, 七品, 青莲, 多场, 广州市, 青少年, 对象, 清廉, 薪火, 行, 充分发挥, 润物细无声, 影响, 作用, 大规模, 培训, 提升, 队伍素质, 监察部, 选调, 分期, 安排, 一个多月, 时间, 分, 三期, 七个, 班次, 县, 近, 人, 一名, 合格, 这一, 主题, 查办, 信访, 举报, 农村, 形势, 妥善处理, 群体性, 事件, 时期, 党的建设, 回顾, 思考, 改革, 发展, 总体, 思路, 内容, 领导班子, 成员, 亲自, 授课, 参加, 相关, 上海, 广东, 湖南, 分级, 从政, 专题, 培训班, 重点, 党政, 党纪政纪, 北京, 乡镇, 延伸, 街道, 重视, 网络, 民意, 切实加强, 舆情, 信息, 深入研究, 互联网, 新兴, 媒体, 准确, 把握, 新形势下, 规律, 不断加强, 收集, 研判, 处置, 主动权, 党中央, 方针政策, 决策, 工作进展, 成效, 特别, 大案要案, 关心, 热点问题, 发布, 权威, 解疑释惑, 网民, 提出, 建议, 回应, 认可, 赞同, 微信, 公众, 号, 马克, 数据网]|
# |2010|[汽车, 以旧换新, 补贴, 标准, 上限, 提高, 万元, 已, 按原, 领取, 车主, 获补, 差额, 本报, 北京, 月, 日电, 记者, 崔鹏, 完善, 政策, 吸引力, 日前, 财政部, 商务部, 联合, 印发, 调整, 事项, 通知, 符合, 实施办法, 提前, 报废, 老旧, 黄标车, 换购, 新车, 元, 车辆, 年, 计算, 终止, 日期, 交售, 回收, 拆解, 企业, 发放, 应, 程序, 确认, 依据, 新, 补发, 资金, 公告, 第二十, 号, 享受, 条件, 补充, 相关, 材料, 后, 部门]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# +----+----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
df_items.orderBy("year").show(5, truncate=False)
# Out:
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |year|content_cleaned                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |items                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |1947|不 投降 消灭 蒋军 九十六 师师 部 被歼 萧里 前线 记者 萧里 报导 人 圩 宿迁 北 歼灭 蒋军 六九 师师 部 十七 日夜 新四军 包围 困守 人 圩 六十九 师师 部 十八日 黄昏 已 整整 昼夜 师师长 戴之奇 仍 无 放下 武器 决心 新四军 至此 总攻 山炮 迫击炮 密集 轰击 八连 战士 张有 沈 詹 沈尤 两人 各携 炸药 一包 潜放至 蒋军 鹿砦 旁 拉开 弹线 霹雳 一声 鹿砦 飞去 指导员 一声 冲锋 机枪 手榴弹 雨点 突击队 跃过 圩 壕 爬 上 圩 墙 一阵 手榴弹 摔 地堡 中 蒋军 进 地堡 一挺 崭新 马克西姆 重机枪 掉转 枪口 一个 地堡 里 冲出 十几个 蒋军 五班 展开 肉搏 杀退 蒋军 两次 冲锋 后 指导员 率领 战士 猛扑 迎面 一个 端 机枪 蒋军 指导员 一手 夺住 蒋军 机枪 一手 抓住 蒋军 脖子 两个 通讯员 紧跟 上 按倒 蒋军 夺下 机枪 转向 蒋军 六十九 师师 部 开火 蒋军 新四军 神勇 动作 慌 都 大批大批 放下 武器 从十时 半三 小时 内 六十九 师师 部 即告 解决 师师长 亦 役 无谓 牺牲                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |[不, 投降, 消灭, 蒋军, 九十六, 师师, 部, 被歼, 萧里, 前线, 记者, 报导, 人, 圩, 宿迁, 北, 歼灭, 六九, 十七, 日夜, 新四军, 包围, 困守, 六十九, 十八日, 黄昏, 已, 整整, 昼夜, 师师长, 戴之奇, 仍, 无, 放下, 武器, 决心, 至此, 总攻, 山炮, 迫击炮, 密集, 轰击, 八连, 战士, 张有, 沈, 詹, 沈尤, 两人, 各携, 炸药, 一包, 潜放至, 鹿砦, 旁, 拉开, 弹线, 霹雳, 一声, 飞去, 指导员, 冲锋, 机枪, 手榴弹, 雨点, 突击队, 跃过, 壕, 爬, 上, 墙, 一阵, 摔, 地堡, 中, 进, 一挺, 崭新, 马克西姆, 重机枪, 掉转, 枪口, 一个, 里, 冲出, 十几个, 五班, 展开, 肉搏, 杀退, 两次, 后, 率领, 猛扑, 迎面, 端, 一手, 夺住, 抓住, 脖子, 两个, 通讯员, 紧跟, 按倒, 夺下, 转向, 开火, 神勇, 动作, 慌, 都, 大批大批, 从十时, 半三, 小时, 内, 即告, 解决, 亦, 役, 无谓, 牺牲]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# |1947|中央局 边府 军区 新年 慰贺 民主 建国 军 西北 民主 联军 全体 将士 中央局 边区 政府 军区 司令部 政治部 元旦 联衔 致电 民主 建国 军及 西北 民主 联军 三十八 军 全体 将士 贺禧 拨款 慰劳 原电 高 总司令 转 民主 建国 军 全体 将士 同志 一九四六年 胜利 中 一九四七年 带 新 来到 面前 急剧 转化 情况 一年 当中 高 总司令 辛勤 领导 全体 将士 同志 努力 民主 建国 军 特别 官兵关系 军民关系 上 飞跃 灿烂 成绩 边区 党政军民 都 非常高兴 引 光荣 不愿 参加 蒋介石 反动 内战 国民党 部队 找寻 光明 道路 启示 新年 佳节 同申 祝贺 之际 特 馈送 每人 冀钞 两百元 新年礼物 以示 慰劳 之微忱 尚祈 哂纳 荷 并颂 新禧 中共 晋冀鲁豫 中央局 晋冀鲁豫 边区 政府 晋冀鲁豫 军区 司令部 晋冀鲁豫 军区 政治部 同启孔 军长 刘副 军长 转 西北 民主 联军 第三十八 军 全体 同志 一年一度 新年 来到 一年 却是 急剧 转化 情况 一年 艰苦奋斗 紧张 一年 终于 战胜 困难 障碍 团结起来 壮大 训练 作战 很大 成绩 边区 党政军民 都 非常高兴 一支 人民 队伍 边区 斗争 发展 实在 一种 荣誉 新年 佳节 同申 祝贺 之际 特 全体 同志 略致 馈仪 三十八 军及 十七 师 每人 冀钞 二百元 五十五 师 每人 冀钞 四百元 新年礼物 以示 慰劳 之微忱 尚祈 哂纳 荷 并颂 禧 新 中共 晋冀鲁豫 中央局 晋冀鲁豫 边区 政府 晋冀鲁豫 军区 司令部 晋冀鲁豫 军区 政治部 同启                                                                                                                                                                                                                                                                                                                                           |[中央局, 边府, 军区, 新年, 慰贺, 民主, 建国, 军, 西北, 联军, 全体, 将士, 边区, 政府, 司令部, 政治部, 元旦, 联衔, 致电, 军及, 三十八, 贺禧, 拨款, 慰劳, 原电, 高, 总司令, 转, 同志, 一九四六年, 胜利, 中, 一九四七年, 带, 新, 来到, 面前, 急剧, 转化, 情况, 一年, 当中, 辛勤, 领导, 努力, 特别, 官兵关系, 军民关系, 上, 飞跃, 灿烂, 成绩, 党政军民, 都, 非常高兴, 引, 光荣, 不愿, 参加, 蒋介石, 反动, 内战, 国民党, 部队, 找寻, 光明, 道路, 启示, 佳节, 同申, 祝贺, 之际, 特, 馈送, 每人, 冀钞, 两百元, 新年礼物, 以示, 之微忱, 尚祈, 哂纳, 荷, 并颂, 新禧, 中共, 晋冀鲁豫, 同启孔, 军长, 刘副, 第三十八, 一年一度, 却是, 艰苦奋斗, 紧张, 终于, 战胜, 困难, 障碍, 团结起来, 壮大, 训练, 作战, 很大, 一支, 人民, 队伍, 斗争, 发展, 实在, 一种, 荣誉, 略致, 馈仪, 十七, 师, 二百元, 五十五, 四百元, 禧, 同启]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# |1947|山东 军区 一年 自卫 作战 共歼 蒋军 十二 万余 今日 山东 解放军 建军 九 周年 纪念日 山东 军区 司令部 顷 公布 一九四六年 自卫战争 光辉 战果 包括 山东 野战军 作战 在内 共 作战 近 五百 次 粉碎 蒋军 无数次 撕毁 停战协定 破坏 和平 阴谋 进攻 作战 中曾 解放 德县 胶县 高密 即墨 泰安 安邱 县 现 胶县 高密 即墨 安邱 已复 遭 蒋军 侵占 攻克 大小 据点 近 三百 处 毙伤 蒋军 官兵 五万 零 三百 九十九 人 击毙 军官 中 包括 六十九 师 原 军 师长 戴之奇 伪 绥靖 军 少将 副司令 金保周 伪 匪首 牛继 鲍秀祥 保 十二 师师长 赵保元 人 生俘 蒋军 六十九 师 副 师长 饶守维及 该师 六十 旅 旅长 黄 保德 九 十二 旅副 旅长 洗盛楷 参谋长 刘历身 七万 一千五百 五十四 人 击落 美制 蒋机 十一架 缴获 六 式 小炮 五百四十 四门 迫击炮 二百八十 五门 山炮 四十八 门 野炮 十五 门 战防炮 八门 九二 步炮 五门 机关炮 二门 汽车 八十五 辆 步马长 短枪 共 十万 四千 二百 卅支 美式 步枪 自动步枪 七百 四十八 支 卡宾式 二百四十 二支 美式 轻机枪 二百三十 三挺 火箭筒 七十八 高射 机枪 二挺 重机枪 二百四十 九挺 轻机枪 汤姆 式 机枪 三千 二百四十 三挺 刺刀 马刀 五千 二百 九十余 马 八百 四 十二匹 步枪 弹 四百 二十六 万 七千四百 余发 炮弹 二万 六千 六百余 发 军用品 无算 三十六年 元旦 山东 解放军 山东 纵队 人民武装 建军 九 周年 纪念日 山东省政府 中共 华东局 新四军 军部 山东 军区 顷特向 全区 发出 联合 通知 略称 山东 人民 中共党员 爱国 人于 二十八年 元旦 建立 组织 人民 武装 民族 社会 解放 浴血 奋斗 游击战 运动战 农村 收复 城市 现 民族 民主革命 胜利 日益 接近 反侵略 道路 已临 翻越 山顶 关头 全区 党政军民 庆祝 外 应 发挥 艰苦奋斗 传统 集 全力 自卫 战 胜利|[山东, 军区, 一年, 自卫, 作战, 共歼, 蒋军, 十二, 万余, 今日, 解放军, 建军, 九, 周年, 纪念日, 司令部, 顷, 公布, 一九四六年, 自卫战争, 光辉, 战果, 包括, 野战军, 在内, 共, 近, 五百, 次, 粉碎, 无数次, 撕毁, 停战协定, 破坏, 和平, 阴谋, 进攻, 中曾, 解放, 德县, 胶县, 高密, 即墨, 泰安, 安邱, 县, 现, 已复, 遭, 侵占, 攻克, 大小, 据点, 三百, 处, 毙伤, 官兵, 五万, 零, 九十九, 人, 击毙, 军官, 中, 六十九, 师, 原, 军, 师长, 戴之奇, 伪, 绥靖, 少将, 副司令, 金保周, 匪首, 牛继, 鲍秀祥, 保, 师师长, 赵保元, 生俘, 副, 饶守维及, 该师, 六十, 旅, 旅长, 黄, 保德, 旅副, 洗盛楷, 参谋长, 刘历身, 七万, 一千五百, 五十四, 击落, 美制, 蒋机, 十一架, 缴获, 六, 式, 小炮, 五百四十, 四门, 迫击炮, 二百八十, 五门, 山炮, 四十八, 门, 野炮, 十五, 战防炮, 八门, 九二, 步炮, 机关炮, 二门, 汽车, 八十五, 辆, 步马长, 短枪, 十万, 四千, 二百, 卅支, 美式, 步枪, 自动步枪, 七百, 支, 卡宾式, 二百四十, 二支, 轻机枪, 二百三十, 三挺, 火箭筒, 七十八, 高射, 机枪, 二挺, 重机枪, 九挺, 汤姆, 三千, 刺刀, 马刀, 五千, 九十余, 马, 八百, 四, 十二匹, 弹, 四百, 二十六, 万, 七千四百, 余发, 炮弹, 二万, 六千, 六百余, 发, 军用品, 无算, 三十六年, 元旦, 纵队, 人民武装, 山东省政府, 中共, 华东局, 新四军, 军部, 顷特向, 全区, 发出, 联合, 通知, 略称, 人民, 中共党员, 爱国, 人于, 二十八年, 建立, 组织, 武装, 民族, 社会, 浴血, 奋斗, 游击战, 运动战, 农村, 收复, 城市, 民主革命, 胜利, 日益, 接近, 反侵略, 道路, 已临, 翻越, 山顶, 关头, 党政军民, 庆祝, 外, 应, 发挥, 艰苦奋斗, 传统, 集, 全力, 战]|
# |1947|我军 炮兵 大显神威 配合 步兵 解决 刘竞 此次 苏北 大 歼灭战 中 新四军 炮兵 大显神威 前线 记者 刘亮 报导 十七日 晚 新四军 反击 困守 晓 店子 宿迁 北 二十里 蒋军 五十七 师 预三旅 旅部 一个团 部队 刚 广阔 平原 上 向前 运动 时 神勇 炮兵 蒋军 阵地 猛 轰 蒋军 火力 压倒 准确 击中 蒋 军工 事 目标 俘虏 兵谈 新四军 炮声 大作 时 蒋军 指挥员 仓皇 躲进 工事 出头露面 致 士兵 指挥 陷入 慌乱 状态 新四军 战士 却 炮兵 准确 射击 兴奋 百倍 爆炸 手 三次 爆破 扫除 蒋军 鹿砦 铁丝网 障碍物 困守 工事 中 蒋军 犹 新四军 山 炮弹 巨响 刹那间 新四军 突击 队 已 蒋 军工 事前 展开 巷战 炮兵 立刻 轰击 蒋军 纵深 阵地 予以 杀伤 配合 步兵 解决 事后 被俘 蒋军 官兵 谈 同声 赞佩 说 指 新四军 炮火 猛 准 真 厉害 真 厉害                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |[我军, 炮兵, 大显神威, 配合, 步兵, 解决, 刘竞, 此次, 苏北, 大, 歼灭战, 中, 新四军, 前线, 记者, 刘亮, 报导, 十七日, 晚, 反击, 困守, 晓, 店子, 宿迁, 北, 二十里, 蒋军, 五十七, 师, 预三旅, 旅部, 一个团, 部队, 刚, 广阔, 平原, 上, 向前, 运动, 时, 神勇, 阵地, 猛, 轰, 火力, 压倒, 准确, 击中, 蒋, 军工, 事, 目标, 俘虏, 兵谈, 炮声, 大作, 指挥员, 仓皇, 躲进, 工事, 出头露面, 致, 士兵, 指挥, 陷入, 慌乱, 状态, 战士, 却, 射击, 兴奋, 百倍, 爆炸, 手, 三次, 爆破, 扫除, 鹿砦, 铁丝网, 障碍物, 犹, 山, 炮弹, 巨响, 刹那间, 突击, 队, 已, 事前, 展开, 巷战, 立刻, 轰击, 纵深, 予以, 杀伤, 事后, 被俘, 官兵, 谈, 同声, 赞佩, 说, 指, 炮火, 准, 真, 厉害]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# |1947|揭载 蒋管区 黑暗 副刊 肖健 编辑 同志 答复 解放区 报纸 蒋管区 公正 报章 上 言论 通讯 转载 介绍 希望 补救 一点 不识货 只怕 货比货 蒋管区 黑暗 更 生动 揭载 解放区 光明面 生活 怀抱 中 心目 中 越发 可爱 乔木 同志 短些 再 短些 这一 提倡 毛主席 送子 上 劳动 大学 一个九岁 儿童 写作 给予 深刻 影响 应是 副刊 努力 方向 书报 介绍 要紧 外 区 出版 茅盾 作 腐蚀 一书 不停 传 看中 报上 应 介绍 应 大众 喉舌 去 督促 解放区 出版事业 翻印 外区 价值 书籍 这方面 走                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |[揭载, 蒋管区, 黑暗, 副刊, 肖健, 编辑, 同志, 答复, 解放区, 报纸, 公正, 报章, 上, 言论, 通讯, 转载, 介绍, 希望, 补救, 一点, 不识货, 只怕, 货比货, 更, 生动, 光明面, 生活, 怀抱, 中, 心目, 越发, 可爱, 乔木, 短些, 再, 这一, 提倡, 毛主席, 送子, 劳动, 大学, 一个九岁, 儿童, 写作, 给予, 深刻, 影响, 应是, 努力, 方向, 书报, 要紧, 外, 区, 出版, 茅盾, 作, 腐蚀, 一书, 不停, 传, 看中, 报上, 应, 大众, 喉舌, 去, 督促, 出版事业, 翻印, 外区, 价值, 书籍, 这方面, 走]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +----+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
year = 1947
df_y = df_items.filter(F.col("year") == year).select("items").cache()
print("Transactions in", year, "=", df_y.count())
# Out:
# [Stage 4:=======================================================> (28 + 1) / 29]
# Transactions in 1947 = 10773

# %% [markdown]
# ### Initial Data Profiling and Support Threshold Setup for 1947 Data
#
# - **Transaction Profiling and Length Distribution**: In this step, I first examined the basic structure of the 1947 dataset used for FP-growth. Each article was treated as a single transaction consisting of unique tokens. In total, 10,773 transactions (articles) were identified. I then calculated the number of unique items per transaction to understand the overall distribution of transaction lengths. The results show that transaction sizes vary substantially: the minimum is 1 item, the median (p50) is 146 items, the 90th percentile is 312, and the maximum is 1,093 items, with an average of approximately 172.87 items per transaction. To better understand these extremes, I also inspected the five longest transactions, all exceeding 900 unique items. This step confirms that while most articles fall within a reasonable range, a small number of very long documents exist and may significantly affect the efficiency of FP-growth if left unfiltered, which provides the basis for deciding whether to delete excessively long or abnormally short transactions in the next stage.
#
# - **Item Document Frequency and Vocabulary Profiling**: In the second step, I calculated the document frequency of each unique item to understand which terms appear most frequently across articles. Since each transaction already contains distinct tokens, each item was counted at most once per document. A total of 159,483 unique items were detected in the 1947 corpus, indicating a very large and diverse vocabulary. I then ranked items by their document frequency and examined the top 20. The most frequent tokens include highly common words such as “中” (6,387 articles), “上” (6,000), “人” (5,426), “后” (5,324), and “不” (5,137), many of which are single-character structural or functional words rather than meaningful content terms, which suggests the presence of quasi-stopwords that may dominate association patterns if not removed.
#
# - **Suggested Support Thresholds and High-Frequency Item Detection**: To prepare for FP-growth, I converted several commonly used relative support values into absolute document counts based on the 1947 dataset. With 10,773 articles in total, a support of 0.5% corresponds to 54 documents, 1% to 108 documents, and 5% to 539 documents. These values provide a practical reference for setting minSupport. I also identified items that appear in more than 30% of all documents (≥ 3,232 articles). A total of 15 such items were found, mostly single-character high-frequency words like “中”, “上”, “人”, and “不”. These terms may dominate the association results and will be considered for removal in the data-cleaning stage before running FP-growth.

# %%
# ---------- STEP 1: basic counts & transaction-length distribution ----------
n_tx = df_y.count()
print(f"[1947] Number of transactions (articles): {n_tx:,}")

df_len = df_y.withColumn("items_len", F.size(F.col("items")))

# Basic stats
len_stats = (df_len.agg(
    F.min("items_len").alias("min_len"),
    F.expr("percentile(items_len, 0.5)").alias("p50_len"),
    F.expr("percentile(items_len, 0.9)").alias("p90_len"),
    F.expr("percentile(items_len, 0.95)").alias("p95_len"),
    F.expr("percentile(items_len, 0.99)").alias("p99_len"),
    F.max("items_len").alias("max_len"),
    F.avg("items_len").alias("avg_len")
).collect()[0])

print("[1947] Transaction length stats (unique items per doc):")
print(f"  min={len_stats['min_len']}, p50={len_stats['p50_len']}, "
      f"p90={len_stats['p90_len']}, p95={len_stats['p95_len']}, "
      f"p99={len_stats['p99_len']}, max={len_stats['max_len']}, "
      f"avg={len_stats['avg_len']:.2f}")

# Inspect a few very long transactions (top-5)
print("\n[1947] Example of longest transactions (top-5 by items_len):")
(df_len.orderBy(F.desc("items_len"))
      .select("items_len", "items")
      .show(5, truncate=80))

# ---------- STEP 2: item document frequency (top terms) ----------
# Each item counted once per document because df_y.items are already distinct.
df_item_freq = (df_y
    .select(F.explode(F.col("items")).alias("item"))
    .groupBy("item").agg(F.count(F.lit(1)).alias("doc_freq"))
    .orderBy(F.desc("doc_freq"))
)

print("\n[1947] Top 20 items by document frequency:")
df_item_freq.show(20, truncate=False)

vocab_size = df_item_freq.count()
print(f"[1947] Vocabulary size (unique items): {vocab_size:,}")

# ---------- STEP 3: suggest minSupport thresholds for FP-growth ----------
# Common ratios to try 
ratios = [0.001, 0.005, 0.01, 0.02, 0.05]
abs_supports = [(r, max(1, math.ceil(r * n_tx))) for r in ratios]

print("\n[1947] Suggested minSupport thresholds (ratio -> absolute doc count):")
for r, a in abs_supports:
    print(f"  {r:.3%} -> {a} docs")

# ---------- flag extremely frequent items ----------
# e.g., items appearing in >30% docs might be near-stopwords for association rules
high_freq_cut = 0.30
high_freq_abs = max(1, math.ceil(high_freq_cut * n_tx))
high_freq_items = (df_item_freq
                   .filter(F.col("doc_freq") >= high_freq_abs)
                   .orderBy(F.desc("doc_freq")))
count_high = high_freq_items.count()
print(f"\n[1947] Items appearing in >= {high_freq_cut:.0%} of docs (>= {high_freq_abs} docs): {count_high}")
if count_high > 0:
    high_freq_items.show(min(20, count_high), truncate=False)
# Out:
# [1947] Number of transactions (articles): 10,773
# [1947] Transaction length stats (unique items per doc):
#   min=1, p50=146.0, p90=312.0, p95=390.0, p99=583.2800000000007, max=1093, avg=172.87
#
# [1947] Example of longest transactions (top-5 by items_len):
# +---------+--------------------------------------------------------------------------------------------------------------------------+
# |items_len|                                                                                                                     items|
# +---------+--------------------------------------------------------------------------------------------------------------------------+
# |     1093|    [不, 真实, 新闻, 客里空, 揭露, 晋绥, 日报, 编辑部, 女, 游击队, 长, 李桂芳, 谈起, 编辑, 工作, 中, 极, 缺点, 稿件, 上...|
# |     1022|[法国社会党, 政策, 齐生, 拉马, 社会党, 内阁, 掌权, 十个月, 终于, 法国, 工人阶级, 罢工, 怒潮, 下台, 五月, 四日, 第奉, 美...|
# |     1020|[九月, 十八日, 联合国大会, 上, 维辛斯基, 演说, 全文, 续完, 战争贩子, 美国, 培育, 新, 战争, 宣传, 地方, 倡导者, 不, 势力...|
# |      937| [人民, 副刊, 蒋军, 必败, 活报剧, 边府, 俱乐部, 集体创作, 周方, 执笔, 第二场, 和平, 出场, 正中, 屏风, 改贴, 大幅, 二字,...|
# |      923|  [南委泉, 土地改革, 运动, 萧寒青, 前, 阶级, 状况, 行政村, 辖, 茶棚, 滩, 东山, 桥上, 数, 小村, 属, 黎城, 五区, 政治经济...|
# +---------+--------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# [1947] Top 20 items by document frequency:
# +----+--------+
# |item|doc_freq|
# +----+--------+
# |中  |6387    |
# |上  |6000    |
# |人  |5426    |
# |后  |5324    |
# |不  |5137    |
# |都  |4968    |
# |已  |4921    |
# |群众|4792    |
# |说  |4356    |
# |时  |4105    |
# |下  |3979    |
# |一个|3902    |
# |组织|3431    |
# |大  |3328    |
# |运动|3280    |
# |二  |3224    |
# |人民|3172    |
# |还  |3120    |
# |工作|3067    |
# |三  |3055    |
# +----+--------+
# only showing top 20 rows
#
# [1947] Vocabulary size (unique items): 159,483
#
# [1947] Suggested minSupport thresholds (ratio -> absolute doc count):
#   0.100% -> 11 docs
#   0.500% -> 54 docs
#   1.000% -> 108 docs
#   2.000% -> 216 docs
#   5.000% -> 539 docs
#
# [1947] Items appearing in >= 30% of docs (>= 3232 docs): 15
# +----+--------+
# |item|doc_freq|
# +----+--------+
# |中  |6387    |
# |上  |6000    |
# |人  |5426    |
# |后  |5324    |
# |不  |5137    |
# |都  |4968    |
# |已  |4921    |
# |群众|4792    |
# |说  |4356    |
# |时  |4105    |
# |下  |3979    |
# |一个|3902    |
# |组织|3431    |
# |大  |3328    |
# |运动|3280    |
# +----+--------+

# %% [markdown]
# - Based on the initial profiling, some transactions were extremely short or unusually long, which could negatively affect FP-growth by introducing noise or causing excessive itemset combinations. To stabilize the transaction size, I first filtered out documents with fewer than 20 items or more than the 99th percentile (583 items). This reduced the dataset from 10,773 to 10,621 documents.
#
# - Next, to reduce the dominance of meaningless co-occurrences, I targeted very common single-character tokens that appeared in more than 30 percent of all documents. Eleven such items were identified and removed from all transactions. After this step, no transactions became empty, and the dataset size remained 10,621.
#
# - I then recalculated the transaction length distribution to ensure the dataset remained consistent. The median basket size was 141 items, the average was 163, and the maximum dropped to 573. This confirms that basket sizes are now more balanced and suitable for frequent pattern mining.
#
# - Finally, using the cleaned dataset size, I recalculated suggested minSupport values for FP-growth. For 10,621 documents, support ratios of 0.5, 1, 2, and 5 percent correspond to 54, 107, 213, and 532 documents respectively. These values will be used as reference points in the next step when running FP-growth.

# %%
# -------------------------------
# STEP 1 & 2: keep 20 <= items_len <= 583
# -------------------------------
df_y_len = df_y.withColumn("items_len", F.size("items"))

before_cnt = df_y_len.count()
print(f"[1947] Before length filter: {before_cnt:,} docs")

df_y_trim = (df_y_len
             .filter((F.col("items_len") >= 20) & (F.col("items_len") <= 583))
             .drop("items_len"))

after_trim_cnt = df_y_trim.count()
print(f"[1947] After length filter (20..583): {after_trim_cnt:,} docs "
      f"({after_trim_cnt/before_cnt:.1%} kept)")

# -------------------------------
# STEP 3: remove high-frequency 1-char items (appear in >=30% of docs)
# -------------------------------
# Compute 1-char item document frequency on the trimmed set
n_tx2 = after_trim_cnt
thr_ratio = 0.30
thr_abs = max(1, math.ceil(thr_ratio * n_tx2))

df_1char_freq = (df_y_trim
    .select(F.explode("items").alias("item"))
    .filter(F.length("item") == 1)
    .groupBy("item").agg(F.count(F.lit(1)).alias("doc_freq"))
    .orderBy(F.desc("doc_freq"))
)

hf_1char = [row["item"] for row in df_1char_freq.filter(F.col("doc_freq") >= thr_abs).collect()]
print(f"[1947] High-frequency 1-char items (>= {thr_ratio:.0%} of docs, >= {thr_abs} docs): {len(hf_1char)}")
print(hf_1char[:50])  # preview first 50

# Remove them from each transaction
if len(hf_1char) > 0:
    stop_arr = F.array(*[F.lit(x) for x in hf_1char])
    df_y_clean = df_y_trim.withColumn("items", F.array_except(F.col("items"), stop_arr))
else:
    df_y_clean = df_y_trim

# Optional: drop any empty transactions after removal (rare but safe)
df_y_clean = df_y_clean.filter(F.size("items") > 0).cache()
clean_cnt = df_y_clean.count()

print(f"[1947] After removing HF 1-char items: {clean_cnt:,} docs "
      f"({clean_cnt/after_trim_cnt:.1%} of trimmed)")

# -------------------------------
# Quick post-clean sanity stats
# -------------------------------
len_stats = (df_y_clean.withColumn("items_len", F.size("items"))
    .agg(
        F.min("items_len").alias("min_len"),
        F.expr("percentile(items_len, 0.5)").alias("p50_len"),
        F.expr("percentile(items_len, 0.9)").alias("p90_len"),
        F.expr("percentile(items_len, 0.95)").alias("p95_len"),
        F.expr("percentile(items_len, 0.99)").alias("p99_len"),
        F.max("items_len").alias("max_len"),
        F.avg("items_len").alias("avg_len")
    ).collect()[0])

print("[1947] Post-clean transaction length stats:")
print(f"  min={len_stats['min_len']}, p50={len_stats['p50_len']}, "
      f"p90={len_stats['p90_len']}, p95={len_stats['p95_len']}, "
      f"p99={len_stats['p99_len']}, max={len_stats['max_len']}, "
      f"avg={len_stats['avg_len']:.2f}")

# Show a small sample after cleaning
print("\n[1947] Sample transactions after cleaning:")
df_y_clean.select("items").show(5, truncate=80)

# Re-suggest minSupport thresholds on the CLEAN set
ratios = [0.005, 0.01, 0.02, 0.05]
print("\n[1947] Suggested minSupport on CLEAN set (ratio -> absolute docs):")
for r in ratios:
    a = max(1, math.ceil(r * clean_cnt))
    print(f"  {r:.1%} -> {a} docs")
# Out:
# [1947] Before length filter: 10,773 docs
# [1947] After length filter (20..583): 10,621 docs (98.6% kept)
# [1947] High-frequency 1-char items (>= 30% of docs, >= 3187 docs): 11
# ['中', '上', '人', '后', '不', '都', '已', '说', '时', '下', '大']
# [Stage 46:======================================================> (28 + 1) / 29]
# [1947] After removing HF 1-char items: 10,621 docs (100.0% of trimmed)
# [1947] Post-clean transaction length stats:
#   min=19, p50=141.0, p90=295.0, p95=362.0, p99=500.0, max=573, avg=163.29
#
# [1947] Sample transactions after cleaning:
# +------------------------------------------------------------------------------------------------------------------------+
# |                                                                                                                   items|
# +------------------------------------------------------------------------------------------------------------------------+
# |[我军, 炮兵, 大显神威, 配合, 步兵, 解决, 刘竞, 此次, 苏北, 歼灭战, 新四军, 前线, 记者, 刘亮, 报导, 十七日, 晚, 反击, ...|
# |[中央局, 边府, 军区, 新年, 慰贺, 民主, 建国, 军, 西北, 联军, 全体, 将士, 边区, 政府, 司令部, 政治部, 元旦, 联衔, 致电...|
# |[山东, 军区, 一年, 自卫, 作战, 共歼, 蒋军, 十二, 万余, 今日, 解放军, 建军, 九, 周年, 纪念日, 司令部, 顷, 公布, 一九四...|
# |  [投降, 消灭, 蒋军, 九十六, 师师, 部, 被歼, 萧里, 前线, 记者, 报导, 圩, 宿迁, 北, 歼灭, 六九, 十七, 日夜, 新四军, 包...|
# |  [新年, 试谈, 副刊, 群众, 林曦, 元旦, 照例, 一篇, 献辞, 空话, 无益, 谈谈, 关系, 一个, 中国, 报纸, 前身, 邸, 抄, 多半...|
# +------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# [1947] Suggested minSupport on CLEAN set (ratio -> absolute docs):
#   0.5% -> 54 docs
#   1.0% -> 107 docs
#   2.0% -> 213 docs
#   5.0% -> 532 docs

# %% [markdown]
# ### Custom stops, FP-Growth run, and rule post-processing
#
# Following the cleaning in Step 3, I added a small custom stop list [‘网’, ‘数’, ‘马’, ‘克’, ‘公众’, ‘号’, ‘微信’] to remove residual non-content tokens and re-cached the cleaned transactions. I then ran FP-Growth on this set with minSupport = 0.02 and minConfidence = 0.30 to obtain frequent itemsets and association rules.
#
# To make lifts interpretable, I restricted to rules with a single-item consequent and computed lift as confidence divided by the consequent’s singleton support. I also required |antecedent| ≥ 2 to avoid trivial rules, then joined back the antecedent’s absolute support and estimated A∪C counts for scale.
#
# Although FP-Growth successfully generated high-confidence and high-lift association rules, the results also revealed a clear limitation: many of the antecedents and consequents are dominated by single-character tokens (e.g., “身”, “翻”, “群”, “人”). These characters tend to be grammatically functional or semantically ambiguous in Chinese, rather than meaningful content words.

# %%
# ---------- A) add custom stopwords and rebuild the clean df ----------
custom_stop = ['网','数','马','克','公众','号','微信']  
stop_arr = F.array(*[F.lit(x) for x in custom_stop])

# start from last clean set
df_y_clean2 = (df_y_clean
               .withColumn("items", F.array_except("items", stop_arr))
               .filter(F.size("items") > 0)
               .cache())
n_tx2 = df_y_clean2.count()
print(f"[CLEAN+] Transactions after custom-stop removal: {n_tx2:,}")

# ---------- B) run FP-Growth ----------
min_sup = 0.02   
min_conf = 0.30  

print(f"[FP] Params: minSupport={min_sup}, minConfidence={min_conf}")
fp = FPGrowth(itemsCol="items", minSupport=min_sup, minConfidence=min_conf)
model = fp.fit(df_y_clean2)

freq = model.freqItemsets.cache()
rules = model.associationRules.cache()

# ---------- C) singleton supports and LIFT for rules with single-item consequent ----------
singleton_support = (freq
    .filter(F.size("items") == 1)
    .select(
        F.col("items")[0].alias("item"),
        (F.col("freq") / F.lit(n_tx2)).alias("support_c_pct")
    )
    .cache()
)

rules_single = (rules
    .filter(F.size("consequent") == 1)
    .withColumn("c_item", F.col("consequent")[0])
    .join(singleton_support.withColumnRenamed("support_c_pct", "support_c_pct"),
          on=(F.col("c_item") == F.col("item")), how="left")
    .drop("item")
    .withColumn("lift", F.col("confidence") / F.col("support_c_pct"))
    # Build ante_key NOW and keep it
    .withColumn("ante_key", F.concat_ws("§", F.array_sort(F.col("antecedent"))))
    .cache()
)

print("\n[Rules] Top 20 by lift (single-item consequent) AFTER custom stops:")
(rules_single
 .orderBy(F.desc("lift"))
 .select("antecedent","consequent","confidence","support_c_pct","lift")
 .show(20, truncate=False))

# ---------- D) require |antecedent| >= 2  ----------
rules_single_k2 = rules_single.filter(F.size("antecedent") >= 2).cache()
print("\n[Rules] Top 20 by lift with |antecedent|>=2:")
(rules_single_k2
 .orderBy(F.desc("lift"))
 .select("antecedent","consequent","confidence","support_c_pct","lift")
 .show(20, truncate=False))

# ---------- E) join antecedent absolute support safely ----------
ante_support = (freq
    .withColumn("key", F.concat_ws("§", F.array_sort("items")))
    .select("key", F.col("freq").alias("ante_freq_abs"))
    .cache()
)

rules_with_counts = (rules_single_k2
    .join(ante_support, rules_single_k2["ante_key"] == ante_support["key"], "left")
    .drop("key")
    .withColumn("union_est_abs", (F.col("confidence") * F.col("ante_freq_abs")).cast("long"))
    .withColumn("union_est_pct", F.col("union_est_abs") / F.lit(n_tx2))
    .cache()
)

print("\n[Rules] With antecedent abs support (top 10 by lift):")
(rules_with_counts
 .orderBy(F.desc("lift"))
 .select("antecedent","consequent","ante_freq_abs","union_est_abs","union_est_pct","confidence","lift")
 .show(10, truncate=False))
# Out:
# [CLEAN+] Transactions after custom-stop removal: 10,621
# [FP] Params: minSupport=0.02, minConfidence=0.3
# 25/11/02 14:27:43 WARN FPGrowth: Input data is not cached.
# [Rules] Top 20 by lift (single-item consequent) AFTER custom stops:
# +----------------+----------+------------------+--------------------+------------------+
# |antecedent      |consequent|confidence        |support_c_pct       |lift              |
# +----------------+----------+------------------+--------------------+------------------+
# |[版]            |[专栏]    |0.8764940239043825|0.021278599001977216|41.191340831364805|
# |[专栏]          |[版]      |0.9734513274336283|0.02363242632520478 |41.191340831364805|
# |[茭]            |[玉]      |0.7574850299401198|0.030223142830241974|25.063079448579476|
# |[玉]            |[茭]      |0.7881619937694704|0.03144713303832031 |25.063079448579476|
# |[缴获, 长]      |[短枪]    |0.7508771929824561|0.03643724696356275 |20.607407407407408|
# |[翻, 翻身, 群众]|[身]      |0.7829181494661922|0.03860276810093211 |20.281399184098603|
# |[翻, 翻身]      |[身]      |0.775811209439528 |0.03860276810093211 |20.09729476940787 |
# |[翻, 领导]      |[身]      |0.7733812949640287|0.03860276810093211 |20.034348131251097|
# |[身, 翻身, 群众]|[翻]      |0.9016393442622951|0.04613501553526033 |19.54349280695885 |
# |[身, 翻身]      |[翻]      |0.8825503355704698|0.04613501553526033 |19.129728804273388|
# |[身, 群众]      |[翻]      |0.873015873015873 |0.04613501553526033 |18.92306446388079 |
# |[翻, 群众]      |[身]      |0.7255936675461742|0.03860276810093211 |18.796415470751015|
# |[身, 领导]      |[翻]      |0.8669354838709677|0.04613501553526033 |18.79126892692561 |
# |[翻, 还]        |[身]      |0.7208588957055214|0.03860276810093211 |18.673761783630106|
# |[身, 还]        |[翻]      |0.8422939068100358|0.04613501553526033 |18.257150171896715|
# |[翻]            |[身]      |0.6979591836734694|0.03860276810093211 |18.080547536087607|
# |[身]            |[翻]      |0.8341463414634146|0.04613501553526033 |18.080547536087607|
# |[挺, 毙伤]      |[重机枪]  |0.7564102564102564|0.044063647490820076|17.16631054131054 |
# |[重机枪, 毙伤]  |[挺]      |0.7866666666666666|0.04613501553526033 |17.05140136054422 |
# |[重机枪]        |[迫击炮]  |0.5064102564102564|0.02975237736559646 |17.020833333333332|
# +----------------+----------+------------------+--------------------+------------------+
# only showing top 20 rows
#
#
# [Rules] Top 20 by lift with |antecedent|>=2:
# +----------------+----------+------------------+--------------------+------------------+
# |antecedent      |consequent|confidence        |support_c_pct       |lift              |
# +----------------+----------+------------------+--------------------+------------------+
# |[缴获, 长]      |[短枪]    |0.7508771929824561|0.03643724696356275 |20.607407407407408|
# |[翻, 翻身, 群众]|[身]      |0.7829181494661922|0.03860276810093211 |20.281399184098603|
# |[翻, 翻身]      |[身]      |0.775811209439528 |0.03860276810093211 |20.09729476940787 |
# |[翻, 领导]      |[身]      |0.7733812949640287|0.03860276810093211 |20.034348131251097|
# |[身, 翻身, 群众]|[翻]      |0.9016393442622951|0.04613501553526033 |19.54349280695885 |
# |[身, 翻身]      |[翻]      |0.8825503355704698|0.04613501553526033 |19.129728804273388|
# |[身, 群众]      |[翻]      |0.873015873015873 |0.04613501553526033 |18.92306446388079 |
# |[翻, 群众]      |[身]      |0.7255936675461742|0.03860276810093211 |18.796415470751015|
# |[身, 领导]      |[翻]      |0.8669354838709677|0.04613501553526033 |18.79126892692561 |
# |[翻, 还]        |[身]      |0.7208588957055214|0.03860276810093211 |18.673761783630106|
# |[身, 还]        |[翻]      |0.8422939068100358|0.04613501553526033 |18.257150171896715|
# |[挺, 毙伤]      |[重机枪]  |0.7564102564102564|0.044063647490820076|17.16631054131054 |
# |[重机枪, 毙伤]  |[挺]      |0.7866666666666666|0.04613501553526033 |17.05140136054422 |
# |[挺, 缴获]      |[重机枪]  |0.7407407407407407|0.044063647490820076|16.810699588477362|
# |[重机枪, 缴获]  |[挺]      |0.7570977917981072|0.04613501553526033 |16.410480911607547|
# |[发, 敌]        |[子弹]    |0.8700361010830325|0.06063459184634215 |14.348840729197033|
# |[发, 步枪]      |[子弹]    |0.847972972972973 |0.06063459184634215 |13.984970412959544|
# |[发, 毙伤]      |[子弹]    |0.8417721518987342|0.06063459184634215 |13.882705008255368|
# |[子弹, 毙伤]    |[发]      |0.8807947019867549|0.06440071556350627 |13.676784400294332|
# |[发, 一部]      |[子弹]    |0.8283582089552238|0.06063459184634215 |13.661479095207193|
# +----------------+----------+------------------+--------------------+------------------+
# only showing top 20 rows
#
#
# [Rules] With antecedent abs support (top 10 by lift):
# +----------------+----------+-------------+-------------+--------------------+------------------+------------------+
# |antecedent      |consequent|ante_freq_abs|union_est_abs|union_est_pct       |confidence        |lift              |
# +----------------+----------+-------------+-------------+--------------------+------------------+------------------+
# |[缴获, 长]      |[短枪]    |285          |214          |0.020148761886827984|0.7508771929824561|20.607407407407408|
# |[翻, 翻身, 群众]|[身]      |281          |220          |0.0207136804444026  |0.7829181494661922|20.281399184098603|
# |[翻, 翻身]      |[身]      |339          |263          |0.024762263440354017|0.775811209439528 |20.09729476940787 |
# |[翻, 领导]      |[身]      |278          |215          |0.020242914979757085|0.7733812949640287|20.034348131251097|
# |[身, 翻身, 群众]|[翻]      |244          |220          |0.0207136804444026  |0.9016393442622951|19.54349280695885 |
# |[身, 翻身]      |[翻]      |298          |263          |0.024762263440354017|0.8825503355704698|19.129728804273388|
# |[身, 群众]      |[翻]      |315          |275          |0.02589210055550325 |0.873015873015873 |18.92306446388079 |
# |[翻, 群众]      |[身]      |379          |275          |0.02589210055550325 |0.7255936675461742|18.796415470751015|
# |[身, 领导]      |[翻]      |248          |215          |0.020242914979757085|0.8669354838709677|18.79126892692561 |
# |[翻, 还]        |[身]      |326          |234          |0.022031823745410038|0.7208588957055214|18.673761783630106|
# +----------------+----------+-------------+-------------+--------------------+------------------+------------------+
# only showing top 10 rows

# %% [markdown]
# ### Remove single-character tokens, rerun FP-Growth, and re-rank rules
#
# To address the earlier issue that many antecedents/consequents were single characters with little semantic value, I filtered each transaction to keep only tokens with length ≥ 2, then re-ran FP-Growth on the cleaned set (minSupport = 0.01, minConfidence = 0.30).
#
# After filtering out single-character tokens and re-running FP-Growth, the association rules became clearer and more meaningful in semantic terms.One example is that: [“全半”, “生产”, “组织”] → [“劳力”] with confidence = 1.0 and lift ≈ 10.7. This rule suggests that whenever articles mention “production”, “organization”, and “work units” together, they almost always involve the concept of “labor”. This aligns closely with the historical context of 1947, when the Chinese Communist Party was actively promoting land reform and agricultural production in liberated areas. Newspapers frequently emphasized mobilizing labor, organizing peasants into production teams, and increasing grain outputs to support the ongoing civil war effort.

# %%
# ===================== Filter to length>=2 tokens, then FP-Growth =====================
custom_stop = ['网','数','马','克','公众','号','微信'] 
stop_arr = F.array(*[F.lit(x) for x in custom_stop])

# 1) Start from previous clean set. 
base_df = df_y_clean2 if 'df_y_clean2' in globals() else df_y_clean

# 2) Remove custom stopwords and ALL single-char tokens; keep only length>=2 tokens
df_y_clean3 = (base_df
    .withColumn("items", F.array_except("items", stop_arr))                # remove custom stops
    .withColumn("items", F.expr("filter(items, x -> length(x) >= 2)"))     # keep tokens with len>=2
    .filter(F.size("items") > 0)
    .cache()
)

n_tx3 = df_y_clean3.count()
print(f"[CLEAN len>=2] Transactions: {n_tx3:,}")

# Quick sanity stats
len_stats = (df_y_clean3.withColumn("items_len", F.size("items"))
    .agg(F.min("items_len").alias("min"),
         F.expr("percentile(items_len, 0.5)").alias("p50"),
         F.expr("percentile(items_len, 0.9)").alias("p90"),
         F.max("items_len").alias("max"),
         F.avg("items_len").alias("avg"))
    .collect()[0])
print(f"[CLEAN len>=2] items per doc -> min={len_stats['min']}, p50={len_stats['p50']}, "
      f"p90={len_stats['p90']}, max={len_stats['max']}, avg={len_stats['avg']:.2f}")

# 3) Run FP-Growth
min_sup = 0.01   
min_conf = 0.30 
print(f"[FP] Params: minSupport={min_sup}, minConfidence={min_conf}")

fp = FPGrowth(itemsCol="items", minSupport=min_sup, minConfidence=min_conf)
model = fp.fit(df_y_clean3)

freq  = model.freqItemsets.cache()
rules = model.associationRules.cache()

print("\n[FP] Frequent itemsets (top 20 by freq):")
freq.orderBy(F.desc("freq")).show(20, truncate=False)

# 4) Compute singleton supports  & LIFT for rules with single-item consequent
singleton_support = (freq
    .filter(F.size("items") == 1)
    .select(F.col("items")[0].alias("item"),
            (F.col("freq")/F.lit(n_tx3)).alias("support_c_pct"))
    .cache()
)

rules_single = (rules
    .filter(F.size("consequent") == 1)
    .withColumn("c_item", F.col("consequent")[0])
    .join(singleton_support, F.col("c_item") == F.col("item"), "left")
    .drop("item")
    .withColumn("lift", F.col("confidence") / F.col("support_c_pct"))
    .withColumn("ante_key", F.concat_ws("§", F.array_sort(F.col("antecedent"))))
    .cache()
)

print("\n[Rules] Top 20 by confidence (single-item consequent, with LIFT):")
(rules_single
 .orderBy(F.desc("confidence"), F.desc("lift"))
 .select("antecedent","consequent","confidence","support_c_pct","lift")
 .show(20, truncate=False))

print("\n[Rules] Top 20 by LIFT (single-item consequent):")
(rules_single
 .orderBy(F.desc("lift"))
 .select("antecedent","consequent","confidence","support_c_pct","lift")
 .show(20, truncate=False))

# Only keep readable rules with |antecedent|>=2
rules_single_k2 = rules_single.filter(F.size("antecedent") >= 2)
print("\n[Rules] |antecedent|>=2, Top 20 by LIFT:")
(rules_single_k2
 .orderBy(F.desc("lift"))
 .select("antecedent","consequent","confidence","support_c_pct","lift")
 .show(20, truncate=False))
# =============================================================================
# Out:
# [CLEAN len>=2] Transactions: 10,621
# [CLEAN len>=2] items per doc -> min=10, p50=118.0, p90=249.0, max=518, avg=137.30
# [FP] Params: minSupport=0.01, minConfidence=0.3
# 25/11/02 14:42:55 WARN FPGrowth: Input data is not cached.
# [FP] Frequent itemsets (top 20 by freq):
# +------------+----+
# |items       |freq|
# +------------+----+
# |[群众]      |4715|
# |[一个]      |3812|
# |[组织]      |3355|
# |[运动]      |3218|
# |[人民]      |3093|
# |[工作]      |2998|
# |[领导]      |2817|
# |[生产]      |2602|
# |[干部]      |2571|
# |[提出]      |2558|
# |[参加]      |2510|
# |[农民]      |2471|
# |[政府]      |2408|
# |[斗争]      |2305|
# |[组织, 群众]|2250|
# |[翻身]      |2193|
# |[运动, 群众]|2174|
# |[计划]      |2122|
# |[领导, 群众]|2072|
# |[同志]      |2042|
# +------------+----+
# only showing top 20 rows
#
#
# [Rules] Top 20 by confidence (single-item consequent, with LIFT):
# +------------------------------+----------+----------+-------------------+------------------+
# |antecedent                    |consequent|confidence|support_c_pct      |lift              |
# +------------------------------+----------+----------+-------------------+------------------+
# |[全半, 生产, 组织]            |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[全半, 领导, 组织]            |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[全半, 生产]                  |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[全半, 领导]                  |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[全半, 妇女]                  |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[全半, 互助, 组织]            |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[全半, 妇女, 组织]            |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[全半, 互助]                  |[劳力]    |1.0       |0.09377648055738631|10.663654618473895|
# |[打通, 讨论, 提出, 运动, 群众]|[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 检查, 干部, 群众]      |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 发现, 讨论]            |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 检查, 领导]            |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 检查, 领导, 群众]      |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 讨论, 提出, 干部, 群众]|[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 讨论, 提出, 运动]      |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 检查, 干部]            |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 讨论, 解决, 群众]      |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 讨论, 解决]            |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 全村, 计划]            |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# |[打通, 全村, 讨论]            |[思想]    |1.0       |0.17051125129460504|5.864715626725566 |
# +------------------------------+----------+----------+-------------------+------------------+
# only showing top 20 rows
#
#
# [Rules] Top 20 by LIFT (single-item consequent):
# +--------------------+----------+-------------------+--------------------+------------------+
# |antecedent          |consequent|confidence         |support_c_pct       |lift              |
# +--------------------+----------+-------------------+--------------------+------------------+
# |[军人]              |[荣退]    |0.43109540636042404|0.011674983523208737|36.92471218511342 |
# |[荣退]              |[军人]    |0.9838709677419355 |0.02664532529893607 |36.924712185113414|
# |[莫斯科, 会议]      |[外长]    |0.605              |0.020901986630260803|28.94461711711712 |
# |[局面, 群众]        |[打开]    |0.5989304812834224 |0.023914885603992093|25.044254494926097|
# |[打开, 群众]        |[局面]    |0.6021505376344086 |0.024103191789850296|24.982190860215056|
# |[将军, 蒋军]        |[刘伯承]  |0.5224489795918368 |0.021372752094906317|24.444628247774883|
# |[独裁, 蒋介石, 人民]|[卖国]    |0.7448275862068966 |0.03078806138781659 |24.1920911104081  |
# |[卖国, 蒋介石, 人民]|[独裁]    |0.5046728971962616 |0.021278599001977216|23.717393102307497|
# |[爆炸, 民兵]        |[地雷]    |0.5707070707070707 |0.02447980416156671 |23.31338383838384 |
# |[独裁, 蒋介石]      |[卖国]    |0.7151515151515152 |0.03078806138781659 |23.22820869242888 |
# |[签订]              |[协定]    |0.5654450261780105 |0.024762263440354017|22.834949137021482|
# |[协定]              |[签订]    |0.41064638783269963|0.01798324074945862 |22.83494913702148 |
# |[短枪, 重机枪, 缴获]|[迫击炮]  |0.6746987951807228 |0.02975237736559646 |22.677138935488788|
# |[重机枪, 毙伤, 歼灭]|[迫击炮]  |0.6646706586826348 |0.02975237736559646 |22.340085651481846|
# |[重机枪, 子弹, 缴获]|[迫击炮]  |0.6547619047619048 |0.02975237736559646 |22.007044906570222|
# |[东北, 民主]        |[联军]    |0.556420233463035  |0.025327181997928633|21.969291076620426|
# |[轻机枪, 重机枪]    |[迫击炮]  |0.6534090909090909 |0.02975237736559646 |21.96157580552359 |
# |[重机枪, 毙伤, 我军]|[迫击炮]  |0.6453488372093024 |0.02975237736559646 |21.690664556962027|
# |[卖国, 人民]        |[独裁]    |0.4600760456273764 |0.021278599001977216|21.621538409771524|
# |[地雷, 民兵]        |[爆炸]    |0.565              |0.026174559834290557|21.585845323741005|
# +--------------------+----------+-------------------+--------------------+------------------+
# only showing top 20 rows
#
#
# [Rules] |antecedent|>=2, Top 20 by LIFT:
# +--------------------+----------+------------------+--------------------+------------------+
# |antecedent          |consequent|confidence        |support_c_pct       |lift              |
# +--------------------+----------+------------------+--------------------+------------------+
# |[莫斯科, 会议]      |[外长]    |0.605             |0.020901986630260803|28.94461711711712 |
# |[局面, 群众]        |[打开]    |0.5989304812834224|0.023914885603992093|25.044254494926097|
# |[打开, 群众]        |[局面]    |0.6021505376344086|0.024103191789850296|24.982190860215056|
# |[将军, 蒋军]        |[刘伯承]  |0.5224489795918368|0.021372752094906317|24.444628247774883|
# |[独裁, 蒋介石, 人民]|[卖国]    |0.7448275862068966|0.03078806138781659 |24.1920911104081  |
# |[卖国, 蒋介石, 人民]|[独裁]    |0.5046728971962616|0.021278599001977216|23.717393102307497|
# |[爆炸, 民兵]        |[地雷]    |0.5707070707070707|0.02447980416156671 |23.31338383838384 |
# |[独裁, 蒋介石]      |[卖国]    |0.7151515151515152|0.03078806138781659 |23.22820869242888 |
# |[短枪, 重机枪, 缴获]|[迫击炮]  |0.6746987951807228|0.02975237736559646 |22.677138935488788|
# |[重机枪, 毙伤, 歼灭]|[迫击炮]  |0.6646706586826348|0.02975237736559646 |22.340085651481846|
# |[重机枪, 子弹, 缴获]|[迫击炮]  |0.6547619047619048|0.02975237736559646 |22.007044906570222|
# |[东北, 民主]        |[联军]    |0.556420233463035 |0.025327181997928633|21.969291076620426|
# |[轻机枪, 重机枪]    |[迫击炮]  |0.6534090909090909|0.02975237736559646 |21.96157580552359 |
# |[重机枪, 毙伤, 我军]|[迫击炮]  |0.6453488372093024|0.02975237736559646 |21.690664556962027|
# |[卖国, 人民]        |[独裁]    |0.4600760456273764|0.021278599001977216|21.621538409771524|
# |[地雷, 民兵]        |[爆炸]    |0.565             |0.026174559834290557|21.585845323741005|
# |[重机枪, 歼灭, 缴获]|[迫击炮]  |0.64              |0.02975237736559646 |21.51088607594937 |
# |[重机枪, 歼灭]      |[迫击炮]  |0.6322869955156951|0.02975237736559646 |21.25164613725379 |
# |[重机枪, 毙伤, 缴获]|[迫击炮]  |0.6302521008403361|0.02975237736559646 |21.18325178172535 |
# |[独裁, 人民]        |[卖国]    |0.6470588235294118|0.03078806138781659 |21.01654973916172 |
# +--------------------+----------+------------------+--------------------+------------------+
# only showing top 20 rows

# %%
# ========== Targeted consequents: 民主 / 群众 / 人民 ==========

# 1) Recompute antecedent absolute support safely
ante_support = (freq
    .withColumn("key", F.concat_ws("§", F.array_sort("items")))
    .select("key", F.col("freq").alias("ante_freq_abs"))
    .cache()
)

# 2) Helper: materialize rules_single with a stable 'ante_key'
rules_single_keyed = (rules_single
    .withColumn("ante_key", F.concat_ws("§", F.array_sort(F.col("antecedent"))))
    .cache()
)

targets = ["民主", "群众", "人民"]  # consequents of interest
min_items_in_antecedent = 2        # require |A| >= 2 for readability
min_ante_abs = 50                  # require antecedent to appear in >= 50 docs (tune)
min_union_abs = 30                 # require estimated |A ∪ C| >= 30 docs (tune)
topk = 20

for tgt in targets:
    print(f"\n================ Target Consequent: {tgt} ================")

    # 3) Filter rules whose consequent equals the target
    rs_tgt = (rules_single_keyed
        .filter((F.size("consequent") == 1) & (F.col("consequent")[0] == tgt))
        .filter(F.size("antecedent") >= min_items_in_antecedent)
        # join antecedent absolute support
        .join(ante_support, rules_single_keyed["ante_key"] == ante_support["key"], "left")
        .drop("key")
        # estimate support for A∪C by conf * |A|
        .withColumn("union_est_abs", (F.col("confidence") * F.col("ante_freq_abs")).cast("long"))
        .withColumn("union_est_pct", F.col("union_est_abs") / F.lit(n_tx3))
        .cache()
    )

    # 4) Apply practical support floors to avoid spurious pairs
    rs_tgt_filt = (rs_tgt
        .filter(F.col("ante_freq_abs") >= F.lit(min_ante_abs))
        .filter(F.col("union_est_abs") >= F.lit(min_union_abs))
        .cache()
    )

    # 5) Show Top-K by lift and by confidence
    print(f"[{tgt}] Top {topk} by LIFT (|A|>={min_items_in_antecedent}, A>= {min_ante_abs} docs, A∪C>= {min_union_abs} docs):")
    (rs_tgt_filt
        .orderBy(F.desc("lift"), F.desc("confidence"))
        .select("antecedent","consequent","ante_freq_abs","union_est_abs","union_est_pct","confidence","support_c_pct","lift")
        .show(topk, truncate=False)
    )

    print(f"[{tgt}] Top {topk} by CONFIDENCE (with same floors):")
    (rs_tgt_filt
        .orderBy(F.desc("confidence"), F.desc("lift"))
        .select("antecedent","consequent","ante_freq_abs","union_est_abs","union_est_pct","confidence","support_c_pct","lift")
        .show(topk, truncate=False)
    )
# Out:
# 25/11/02 14:57:51 WARN CacheManager: Asked to cache already cached data.
# 25/11/02 14:57:51 WARN CacheManager: Asked to cache already cached data.
#
# ================ Target Consequent: 民主 ================
# 25/11/02 14:57:51 WARN CacheManager: Asked to cache already cached data.
# 25/11/02 14:57:51 WARN CacheManager: Asked to cache already cached data.
# [民主] Top 20 by LIFT (|A|>=2, A>= 50 docs, A∪C>= 30 docs):
# +--------------------------+----------+-------------+-------------+--------------------+------------------+-------------------+-----------------+
# |antecedent                |consequent|ante_freq_abs|union_est_abs|union_est_pct       |confidence        |support_c_pct      |lift             |
# +--------------------------+----------+-------------+-------------+--------------------+------------------+-------------------+-----------------+
# |[联军, 收复]              |[民主]    |112          |112          |0.010545146408059505|1.0               |0.17766688635721684|5.628510863804982|
# |[联军, 我军]              |[民主]    |108          |108          |0.010168534036343093|1.0               |0.17766688635721684|5.628510863804982|
# |[联军, 蒋军]              |[民主]    |155          |153          |0.014405423218152717|0.9870967741935484|0.17766688635721684|5.55588491717524 |
# |[联军, 东北]              |[民主]    |145          |143          |0.01346389228886169 |0.9862068965517241|0.17766688635721684|5.550876231200775|
# |[联军, 一个]              |[民主]    |123          |120          |0.011298371151492327|0.975609756097561 |0.17766688635721684|5.49123011102925 |
# |[联军, 人民]              |[民主]    |114          |111          |0.010450993315130401|0.9736842105263158|0.17766688635721684|5.480392156862745|
# |[独立, 和平, 人民]        |[民主]    |182          |148          |0.013934657753507202|0.8131868131868132|0.17766688635721684|4.57703081232493 |
# |[自由, 和平, 人民]        |[民主]    |147          |118          |0.01111006496563412 |0.8027210884353742|0.17766688635721684|4.518124366863863|
# |[自由, 和平]              |[民主]    |168          |134          |0.012616514452499764|0.7976190476190477|0.17766688635721684|4.489407474701593|
# |[和平, 内战, 中国, 人民]  |[民主]    |137          |108          |0.010168534036343093|0.7883211678832117|0.17766688635721684|4.437074257598088|
# |[和平, 中国, 反对]        |[民主]    |143          |112          |0.010545146408059505|0.7832167832167832|0.17766688635721684|4.408344173050056|
# |[独立, 和平]              |[民主]    |216          |169          |0.01591187270501836 |0.7824074074074074|0.17766688635721684|4.403788592514083|
# |[独立, 中国, 人民]        |[民主]    |147          |115          |0.010827605686846813|0.782312925170068 |0.17766688635721684|4.403256798214781|
# |[反动, 和平]              |[民主]    |138          |107          |0.010074380943413992|0.7753623188405797|0.17766688635721684|4.364135234979225|
# |[和平, 反对, 政府, 人民]  |[民主]    |169          |131          |0.012334055173712456|0.7751479289940828|0.17766688635721684|4.362928539399127|
# |[和平, 中国, 蒋介石, 人民]|[民主]    |151          |116          |0.010921758779775916|0.7682119205298014|0.17766688635721684|4.323889140406476|
# |[独立, 蒋介石]            |[民主]    |145          |111          |0.010450993315130401|0.7655172413793103|0.17766688635721684|4.308722109533468|
# |[独立, 反对, 人民]        |[民主]    |168          |128          |0.012051595894925148|0.7619047619047619|0.17766688635721684|4.2883892295657  |
# |[全国, 和平, 人民]        |[民主]    |159          |121          |0.011392524244421429|0.7610062893081762|0.17766688635721684|4.283332166794986|
# |[和平, 内战, 中国]        |[民主]    |154          |117          |0.011015911872705019|0.7597402597402597|0.17766688635721684|4.276206305618071|
# +--------------------------+----------+-------------+-------------+--------------------+------------------+-------------------+-----------------+
# only showing top 20 rows
#
# [民主] Top 20 by CONFIDENCE (with same floors):
# +--------------------------+----------+-------------+-------------+--------------------+------------------+-------------------+-----------------+
# |antecedent                |consequent|ante_freq_abs|union_est_abs|union_est_pct       |confidence        |support_c_pct      |lift             |
# +--------------------------+----------+-------------+-------------+--------------------+------------------+-------------------+-----------------+
# |[联军, 收复]              |[民主]    |112          |112          |0.010545146408059505|1.0               |0.17766688635721684|5.628510863804982|
# |[联军, 我军]              |[民主]    |108          |108          |0.010168534036343093|1.0               |0.17766688635721684|5.628510863804982|
# |[联军, 蒋军]              |[民主]    |155          |153          |0.014405423218152717|0.9870967741935484|0.17766688635721684|5.55588491717524 |
# |[联军, 东北]              |[民主]    |145          |143          |0.01346389228886169 |0.9862068965517241|0.17766688635721684|5.550876231200775|
# |[联军, 一个]              |[民主]    |123          |120          |0.011298371151492327|0.975609756097561 |0.17766688635721684|5.49123011102925 |
# |[联军, 人民]              |[民主]    |114          |111          |0.010450993315130401|0.9736842105263158|0.17766688635721684|5.480392156862745|
# |[独立, 和平, 人民]        |[民主]    |182          |148          |0.013934657753507202|0.8131868131868132|0.17766688635721684|4.57703081232493 |
# |[自由, 和平, 人民]        |[民主]    |147          |118          |0.01111006496563412 |0.8027210884353742|0.17766688635721684|4.518124366863863|
# |[自由, 和平]              |[民主]    |168          |134          |0.012616514452499764|0.7976190476190477|0.17766688635721684|4.489407474701593|
# |[和平, 内战, 中国, 人民]  |[民主]    |137          |108          |0.010168534036343093|0.7883211678832117|0.17766688635721684|4.437074257598088|
# |[和平, 中国, 反对]        |[民主]    |143          |112          |0.010545146408059505|0.7832167832167832|0.17766688635721684|4.408344173050056|
# |[独立, 和平]              |[民主]    |216          |169          |0.01591187270501836 |0.7824074074074074|0.17766688635721684|4.403788592514083|
# |[独立, 中国, 人民]        |[民主]    |147          |115          |0.010827605686846813|0.782312925170068 |0.17766688635721684|4.403256798214781|
# |[反动, 和平]              |[民主]    |138          |107          |0.010074380943413992|0.7753623188405797|0.17766688635721684|4.364135234979225|
# |[和平, 反对, 政府, 人民]  |[民主]    |169          |131          |0.012334055173712456|0.7751479289940828|0.17766688635721684|4.362928539399127|
# |[和平, 中国, 蒋介石, 人民]|[民主]    |151          |116          |0.010921758779775916|0.7682119205298014|0.17766688635721684|4.323889140406476|
# |[独立, 蒋介石]            |[民主]    |145          |111          |0.010450993315130401|0.7655172413793103|0.17766688635721684|4.308722109533468|
# |[独立, 反对, 人民]        |[民主]    |168          |128          |0.012051595894925148|0.7619047619047619|0.17766688635721684|4.2883892295657  |
# |[全国, 和平, 人民]        |[民主]    |159          |121          |0.011392524244421429|0.7610062893081762|0.17766688635721684|4.283332166794986|
# |[和平, 内战, 中国]        |[民主]    |154          |117          |0.011015911872705019|0.7597402597402597|0.17766688635721684|4.276206305618071|
# +--------------------------+----------+-------------+-------------+--------------------+------------------+-------------------+-----------------+
# only showing top 20 rows
#
#
# ================ Target Consequent: 群众 ================
# [群众] Top 20 by LIFT (|A|>=2, A>= 50 docs, A∪C>= 30 docs):
# +--------------------------------------+----------+-------------+-------------+--------------------+----------+------------------+------------------+
# |antecedent                            |consequent|ante_freq_abs|union_est_abs|union_est_pct       |confidence|support_c_pct     |lift              |
# +--------------------------------------+----------+-------------+-------------+--------------------+----------+------------------+------------------+
# |[发动群众, 发动, 干部, 领导]          |[群众]    |108          |108          |0.010168534036343093|1.0       |0.4439318331607193|2.2525980911983035|
# |[发动群众, 干部, 运动, 组织]          |[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[土地, 解决, 提出, 干部, 领导]        |[群众]    |116          |116          |0.010921758779775916|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 地主, 农民, 干部, 工作]        |[群众]    |139          |139          |0.013087279917145278|1.0       |0.4439318331607193|2.2525980911983035|
# |[村干部, 斗争, 农民, 领导]            |[群众]    |157          |157          |0.014782035589869126|1.0       |0.4439318331607193|2.2525980911983035|
# |[发展, 思想, 农民, 干部, 领导]        |[群众]    |118          |118          |0.01111006496563412 |1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 检查, 斗争, 干部, 领导, 运动]  |[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 检查, 土地, 领导]              |[群众]    |109          |109          |0.010262687129272197|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 翻身, 斗争, 农民, 工作, 运动]  |[群众]    |114          |114          |0.01073345259391771 |1.0       |0.4439318331607193|2.2525980911983035|
# |[教育, 土地, 思想, 干部, 领导]        |[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[发动, 思想, 翻身, 农民, 干部, 工作]  |[群众]    |114          |114          |0.01073345259391771 |1.0       |0.4439318331607193|2.2525980911983035|
# |[村干部, 翻身, 斗争, 农民, 领导, 运动]|[群众]    |110          |110          |0.0103568402222013  |1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 翻身, 斗争, 农民, 干部, 工作]  |[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[经验, 解决, 农民, 提出, 领导, 组织]  |[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[发动, 思想, 斗争, 农民, 干部, 工作]  |[群众]    |108          |108          |0.010168534036343093|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 农民, 提出, 干部, 工作]        |[群众]    |113          |113          |0.010639299500988608|1.0       |0.4439318331607193|2.2525980911983035|
# |[意见, 地主, 斗争, 干部, 领导]        |[群众]    |123          |123          |0.011580830430279635|1.0       |0.4439318331607193|2.2525980911983035|
# |[自觉, 思想, 农民, 领导, 运动]        |[群众]    |114          |114          |0.01073345259391771 |1.0       |0.4439318331607193|2.2525980911983035|
# |[教育, 发动, 农民, 干部, 领导]        |[群众]    |111          |111          |0.010450993315130401|1.0       |0.4439318331607193|2.2525980911983035|
# |[发展, 农民, 干部, 生产, 领导]        |[群众]    |108          |108          |0.010168534036343093|1.0       |0.4439318331607193|2.2525980911983035|
# +--------------------------------------+----------+-------------+-------------+--------------------+----------+------------------+------------------+
# only showing top 20 rows
#
# [群众] Top 20 by CONFIDENCE (with same floors):
# +------------------------------------+----------+-------------+-------------+--------------------+----------+------------------+------------------+
# |antecedent                          |consequent|ante_freq_abs|union_est_abs|union_est_pct       |confidence|support_c_pct     |lift              |
# +------------------------------------+----------+-------------+-------------+--------------------+----------+------------------+------------------+
# |[发动群众, 发动, 干部, 领导]        |[群众]    |108          |108          |0.010168534036343093|1.0       |0.4439318331607193|2.2525980911983035|
# |[发动群众, 斗争, 干部, 领导]        |[群众]    |114          |114          |0.01073345259391771 |1.0       |0.4439318331607193|2.2525980911983035|
# |[东西, 农民, 提出, 领导, 运动]      |[群众]    |115          |115          |0.010827605686846813|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 地主, 农民, 干部, 领导, 工作]|[群众]    |117          |117          |0.011015911872705019|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 地主, 斗争, 农民, 干部, 工作]|[群众]    |123          |123          |0.011580830430279635|1.0       |0.4439318331607193|2.2525980911983035|
# |[村庄, 翻身, 斗争, 领导, 运动]      |[群众]    |118          |118          |0.01111006496563412 |1.0       |0.4439318331607193|2.2525980911983035|
# |[自觉, 斗争, 干部, 领导, 运动]      |[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[土地, 解决, 提出, 干部, 领导]      |[群众]    |116          |116          |0.010921758779775916|1.0       |0.4439318331607193|2.2525980911983035|
# |[意见, 斗争, 农民, 干部, 领导]      |[群众]    |115          |115          |0.010827605686846813|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 斗争, 农民, 干部, 工作]      |[群众]    |141          |141          |0.013275586103003483|1.0       |0.4439318331607193|2.2525980911983035|
# |[经验, 解决, 农民, 提出, 领导, 组织]|[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 思想, 地主, 农民, 工作]      |[群众]    |109          |109          |0.010262687129272197|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 翻身, 斗争, 农民, 工作, 运动]|[群众]    |114          |114          |0.01073345259391771 |1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 翻身, 斗争, 农民, 干部, 工作]|[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 检查, 土地, 领导]            |[群众]    |109          |109          |0.010262687129272197|1.0       |0.4439318331607193|2.2525980911983035|
# |[发动, 解决, 农民, 领导, 工作]      |[群众]    |110          |110          |0.0103568402222013  |1.0       |0.4439318331607193|2.2525980911983035|
# |[果实, 检查, 斗争, 干部, 领导, 运动]|[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[发动群众, 干部, 运动, 组织]        |[群众]    |107          |107          |0.010074380943413992|1.0       |0.4439318331607193|2.2525980911983035|
# |[太行, 斗争, 领导]                  |[群众]    |118          |118          |0.01111006496563412 |1.0       |0.4439318331607193|2.2525980911983035|
# |[发展, 思想, 农民, 干部, 领导]      |[群众]    |118          |118          |0.01111006496563412 |1.0       |0.4439318331607193|2.2525980911983035|
# +------------------------------------+----------+-------------+-------------+--------------------+----------+------------------+------------------+
# only showing top 20 rows
#
#
# ================ Target Consequent: 人民 ================
# [人民] Top 20 by LIFT (|A|>=2, A>= 50 docs, A∪C>= 30 docs):
# +--------------------------+----------+-------------+-------------+--------------------+------------------+------------------+------------------+
# |antecedent                |consequent|ante_freq_abs|union_est_abs|union_est_pct       |confidence        |support_c_pct     |lift              |
# +--------------------------+----------+-------------+-------------+--------------------+------------------+------------------+------------------+
# |[和平, 反对, 胜利]        |[人民]    |116          |110          |0.0103568402222013  |0.9482758620689655|0.2912155164297147|3.256268325585025 |
# |[爱国, 中国, 蒋介石]      |[人民]    |130          |123          |0.011580830430279635|0.9461538461538461|0.2912155164297147|3.2489815712900096|
# |[全国, 解放区, 蒋介石]    |[人民]    |129          |122          |0.011486677337350532|0.9457364341085271|0.2912155164297147|3.247548227179653 |
# |[爱国, 美国]              |[人民]    |126          |119          |0.011204218058563224|0.9444444444444444|0.2912155164297147|3.2431116858856917|
# |[卖国, 和平]              |[人民]    |118          |111          |0.010450993315130401|0.940677966101695 |0.2912155164297147|3.2301780400795677|
# |[和平, 政策, 民主, 政府]  |[人民]    |114          |107          |0.010074380943413992|0.9385964912280702|0.2912155164297147|3.223030498976183 |
# |[帝国主义, 力量]          |[人民]    |127          |119          |0.011204218058563224|0.937007874015748 |0.2912155164297147|3.217575373398403 |
# |[卖国, 全国]              |[人民]    |124          |116          |0.010921758779775916|0.9354838709677419|0.2912155164297147|3.212342125298541 |
# |[全国, 中国, 蒋介石]      |[人民]    |155          |145          |0.013652198474719894|0.9354838709677419|0.2912155164297147|3.212342125298541 |
# |[卖国, 反对]              |[人民]    |139          |130          |0.012239902080783354|0.935251798561151 |0.2912155164297147|3.211545215815708 |
# |[反动, 和平]              |[人民]    |138          |129          |0.012145748987854251|0.9347826086956522|0.2912155164297147|3.209934072730851 |
# |[和平, 政策, 反对, 政府]  |[人民]    |118          |110          |0.0103568402222013  |0.9322033898305084|0.2912155164297147|3.2010773370157874|
# |[内战, 中国, 反对, 蒋介石]|[人民]    |132          |123          |0.011580830430279635|0.9318181818181818|0.2912155164297147|3.1997545777856153|
# |[卖国, 反对, 蒋介石]      |[人民]    |115          |107          |0.010074380943413992|0.9304347826086956|0.2912155164297147|3.1950041468111725|
# |[国家, 和平, 力量]        |[人民]    |115          |107          |0.010074380943413992|0.9304347826086956|0.2912155164297147|3.1950041468111725|
# |[爱国, 反对]              |[人民]    |128          |119          |0.011204218058563224|0.9296875         |0.2912155164297147|3.192438065793728 |
# |[全国, 美国, 蒋介石]      |[人民]    |128          |119          |0.011204218058563224|0.9296875         |0.2912155164297147|3.192438065793728 |
# |[和平, 反对, 民主, 政府]  |[人民]    |141          |131          |0.012334055173712456|0.9290780141843972|0.2912155164297147|3.1903451628362376|
# |[和平, 中国, 蒋介石, 民主]|[人民]    |125          |116          |0.010921758779775916|0.928             |0.2912155164297147|3.1866433882961527|
# |[和平, 反对, 组织]        |[人民]    |124          |115          |0.010827605686846813|0.9274193548387096|0.2912155164297147|3.184649520770105 |
# +--------------------------+----------+-------------+-------------+--------------------+------------------+------------------+------------------+
# only showing top 20 rows
#
# [人民] Top 20 by CONFIDENCE (with same floors):
# +--------------------------+----------+-------------+-------------+--------------------+------------------+------------------+------------------+
# |antecedent                |consequent|ante_freq_abs|union_est_abs|union_est_pct       |confidence        |support_c_pct     |lift              |
# +--------------------------+----------+-------------+-------------+--------------------+------------------+------------------+------------------+
# |[和平, 反对, 胜利]        |[人民]    |116          |110          |0.0103568402222013  |0.9482758620689655|0.2912155164297147|3.256268325585025 |
# |[爱国, 中国, 蒋介石]      |[人民]    |130          |123          |0.011580830430279635|0.9461538461538461|0.2912155164297147|3.2489815712900096|
# |[全国, 解放区, 蒋介石]    |[人民]    |129          |122          |0.011486677337350532|0.9457364341085271|0.2912155164297147|3.247548227179653 |
# |[爱国, 美国]              |[人民]    |126          |119          |0.011204218058563224|0.9444444444444444|0.2912155164297147|3.2431116858856917|
# |[卖国, 和平]              |[人民]    |118          |111          |0.010450993315130401|0.940677966101695 |0.2912155164297147|3.2301780400795677|
# |[和平, 政策, 民主, 政府]  |[人民]    |114          |107          |0.010074380943413992|0.9385964912280702|0.2912155164297147|3.223030498976183 |
# |[帝国主义, 力量]          |[人民]    |127          |119          |0.011204218058563224|0.937007874015748 |0.2912155164297147|3.217575373398403 |
# |[全国, 中国, 蒋介石]      |[人民]    |155          |145          |0.013652198474719894|0.9354838709677419|0.2912155164297147|3.212342125298541 |
# |[卖国, 全国]              |[人民]    |124          |116          |0.010921758779775916|0.9354838709677419|0.2912155164297147|3.212342125298541 |
# |[卖国, 反对]              |[人民]    |139          |130          |0.012239902080783354|0.935251798561151 |0.2912155164297147|3.211545215815708 |
# |[反动, 和平]              |[人民]    |138          |129          |0.012145748987854251|0.9347826086956522|0.2912155164297147|3.209934072730851 |
# |[和平, 政策, 反对, 政府]  |[人民]    |118          |110          |0.0103568402222013  |0.9322033898305084|0.2912155164297147|3.2010773370157874|
# |[内战, 中国, 反对, 蒋介石]|[人民]    |132          |123          |0.011580830430279635|0.9318181818181818|0.2912155164297147|3.1997545777856153|
# |[国家, 和平, 力量]        |[人民]    |115          |107          |0.010074380943413992|0.9304347826086956|0.2912155164297147|3.1950041468111725|
# |[卖国, 反对, 蒋介石]      |[人民]    |115          |107          |0.010074380943413992|0.9304347826086956|0.2912155164297147|3.1950041468111725|
# |[全国, 美国, 蒋介石]      |[人民]    |128          |119          |0.011204218058563224|0.9296875         |0.2912155164297147|3.192438065793728 |
# |[爱国, 反对]              |[人民]    |128          |119          |0.011204218058563224|0.9296875         |0.2912155164297147|3.192438065793728 |
# |[和平, 反对, 民主, 政府]  |[人民]    |141          |131          |0.012334055173712456|0.9290780141843972|0.2912155164297147|3.1903451628362376|
# |[和平, 中国, 蒋介石, 民主]|[人民]    |125          |116          |0.010921758779775916|0.928             |0.2912155164297147|3.1866433882961527|
# |[独立, 中国, 民主]        |[人民]    |124          |115          |0.010827605686846813|0.9274193548387096|0.2912155164297147|3.184649520770105 |
# +--------------------------+----------+-------------+-------------+--------------------+------------------+------------------+------------------+
# only showing top 20 rows
